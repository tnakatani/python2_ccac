# %%
import pandas as pd
import numpy as np

df = pd.read_csv('data/allegheny_county_food_violations.csv')

# %%
df.head()
# Out:
#       encounter     id  placard_st  \
# 0  201502270009  10762           1
# 1  201502270009  10762           1
# 2  201602100042  10762           1
# 3  201602100042  10762           1
# 4  201602100042  10762           1
#
#                                        facility_name bus_st_date  \
# 0  North Versailles VFD / South Wilmerding Social...  1969-01-01
# 1  North Versailles VFD / South Wilmerding Social...  1969-01-01
# 2  North Versailles VFD / South Wilmerding Social...  1969-01-01
# 3  North Versailles VFD / South Wilmerding Social...  1969-01-01
# 4  North Versailles VFD / South Wilmerding Social...  1969-01-01
#
#             description                                    description_new  \
# 0  Social Club-Bar Only                             Handwashing Facilities
# 1  Social Club-Bar Only  Fabrication, Design, Installation and Maintenance
# 2  Social Club-Bar Only                          Employee Personal Hygiene
# ...

# %%
df.dtypes
# Out:
# encounter            int64
# id                   int64
# placard_st           int64
# facility_name       object
# bus_st_date         object
# description         object
# description_new     object
# num                 object
# street              object
# city                object
# state               object
# zip                float64
# inspect_dt          object
# start_time          object
# end_time            object
# municipal           object
# rating              object
# low                 object
# medium              object
# high                object
# url                 object
# dtype: object

# %%
df.describe(include='all')
# Out:
#            encounter            id     placard_st          facility_name  \
# count   2.388590e+05  2.388590e+05  238859.000000                 236827
# unique           NaN           NaN            NaN                  10066
# top              NaN           NaN            NaN  Italian Village Pizza
# freq             NaN           NaN            NaN                    824
# mean    2.016672e+11  1.494417e+11       1.025212                    NaN
# std     1.573061e+08  8.784050e+10       0.244476                    NaN
# min     2.014010e+11  1.000000e+01       0.000000                    NaN
# 25%     2.015101e+11  5.754200e+04       1.000000                    NaN
# 50%     2.017010e+11  2.008103e+11       1.000000                    NaN
# 75%     2.018061e+11  2.014072e+11       1.000000                    NaN
# max     2.019123e+11  2.019123e+11       7.000000                    NaN
#
#        bus_st_date             description            description_new     num  \
# ...
