# %%
import pandas as pd

df = pd.read_csv('../data/pgh_capital_projects.csv')

# %% [markdown]
# ## Create Frequency Table of Null Values

# %%
df.isnull().sum()
# Out:
# id                         0
# name                       2
# task_description           7
# area                       2
# budgeted_amount            3
# status                     0
# asset_id                 478
# asset_type                 0
# fiscal_year                0
# start_date                 0
# inactive                 394
# neighborhood             378
# council_district         376
# ward                     378
# tract                    374
# public_works_division    378
# pli_division             378
# police_zone              379
# fire_zone                378
# latitude                   0
# longitude                  0
# dtype: int64

# %%
df.loc[df.isnull().any(axis=1)]
# Out:
#              id                                              name  \
# 7    1911757466      McFARREN STREET (SECOND AVENUE) BRIDGE (TIP)
# 8    1537317222      McFARREN STREET (SECOND AVENUE) BRIDGE (TIP)
# 77    571915867           CITY COUNCIL'S UNSPECIFIED LOCAL OPTION
# 78   2143189705           CITY COUNCIL'S UNSPECIFIED LOCAL OPTION
# 79   1364486196           CITY COUNCIL'S UNSPECIFIED LOCAL OPTION
# ..          ...                                               ...
# 805  1797590590                         SLOPE FAILURE REMEDIATION
# 806   113484596                                 TRAIL DEVELOPMENT
# 807   691823479                            PLAY AREA IMPROVEMENTS
# 808  1947652660                                               NaN
# 809   789506120  FACILITY IMPROVEMENTS - PUBLIC SAFETY FACILITIES
#
#                                    task_description  \
# 7                   Final Design, Utility Clearance
# 8                   Final Design, Utility Clearance
# 77   Brashear Association (for Arlington Food Bank)
# 78                         Community Human Services
# 79                   Emmaus Community of Pittsburgh
# ..                                              ...
# 805            UPPER GREENLEAF - SLOPE IMPROVEMENTS
# 806                 MONITOR ST TO FORWARD AVE TRAIL
# 807              SUE MURRAY PLAYGROUND IMPROVEMENTS
# 808                                       demo park
# 809                  FIRE STATION INTERIOR UPGRADES
#
#                              area  budgeted_amount       status  \
# 7    Engineering and Construction          35750.0  In Progress
# 8    Engineering and Construction         679250.0  In Progress
# 77       Administration/Sub-Award           2500.0  In Progress
# 78       Administration/Sub-Award           2500.0      Planned
# 79       Administration/Sub-Award           2500.0      Planned
# ..                            ...              ...          ...
# 805  Engineering and Construction         750000.0      Planned
# 806  Engineering and Construction          50000.0      Planned
# 807          Facility Improvement          38244.0    Completed
# 808                           NaN              NaN    Completed
# 809          Facility Improvement         407873.0  In Progress
#
#                          asset_id  asset_type  fiscal_year  start_date  ...  \
# 7             MacFarren St Bridge      Bridge         2018  2018-02-08  ...
# 8             MacFarren St Bridge      Bridge         2018  2018-02-08  ...
# 77                            NaN   Non-Asset         2018  2018-02-08  ...
# 78                            NaN   Non-Asset         2017  2017-02-08  ...
# 79                            NaN   Non-Asset         2017  2017-02-08  ...
# ..                            ...         ...          ...         ...  ...
# 805                           NaN   Non-Asset         2019  2019-03-22  ...
# 806                           NaN   Non-Asset         2019  2019-03-22  ...
# 807         Sue Murray Playground  Playground         2019  2019-03-26  ...
# 808  Fineview Park Sports Court 1       Court         2019  2019-04-23  ...
# 809                           NaN   Non-Asset         2019  2019-07-05  ...
#
#             neighborhood council_district  ward         tract  \
# 7                    NaN              5.0   NaN  4.200314e+10
# 8                    NaN              5.0   NaN  4.200314e+10
# 77             Allentown              3.0  18.0  4.200318e+10
# 78       Central Oakland              3.0   4.0  4.200304e+10
# 79      South Side Flats              3.0  16.0  4.200316e+10
# ..                   ...              ...   ...           ...
# 805     Duquesne Heights              2.0  19.0  4.200319e+10
# 806  Squirrel Hill South              5.0  14.0  4.200314e+10
# 807     Allegheny Center              1.0  22.0  4.200356e+10
# 808             Fineview              1.0  25.0  4.200325e+10
# 809                  NaN              NaN   NaN           NaN
#
#      public_works_division  pli_division  police_zone  fire_zone   latitude  \
# 7                      NaN           NaN          NaN        NaN  40.415161
# 8                      NaN           NaN          NaN        NaN  40.415161
# 77                     5.0          18.0          3.0       4-21  40.421620
# 78                     3.0           4.0          4.0       2-11  40.437560
# 79                     3.0          16.0          3.0       4-24  40.425460
# ..                     ...           ...          ...        ...        ...
# 805                    5.0          19.0          3.0        4-1  40.442619
# 806                    3.0          14.0          4.0       2-15  40.426277
# 807                    1.0          22.0          1.0        1-6  40.451632
# 808                    1.0          25.0          1.0       1-10  40.461753
# 809                    NaN           NaN          NaN        NaN   0.000000
#
#      longitude
# 7   -79.915649
# 8   -79.915649
# 77  -79.994561
# 78  -79.953521
# 79  -79.965961
# ..         ...
# 805 -80.028675
# 806 -79.926259
# 807 -80.001547
# 808 -80.003982
# 809   0.000000
#
# [497 rows x 21 columns]
